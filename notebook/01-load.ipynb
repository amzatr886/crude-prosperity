# %% [markdown]
# # Load Data

# %% [markdown]
# ##  World Gdp Data

# %%
import pandas as pd # for data manipulation

# %%
gdp = pd.read_csv('../data/raw/world-gdp.csv')
# view the head of the data
gdp.head(10)
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
# 5                      Albania          ALB  GDP (current US$)
# 6                      Andorra          AND  GDP (current US$)
# 7                   Arab World          ARB  GDP (current US$)
# 8         United Arab Emirates          ARE  GDP (current US$)
# 9                    Argentina          ARG  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.112502e+10  2.161623e+10  2.350628e+10  2.804836e+10
# ...

# %%
# view the tail of the data
gdp.tail(15)
# Out:
#                        Country Name Country Code     Indicator Name  \
# 251                   United States          USA  GDP (current US$)
# 252                      Uzbekistan          UZB  GDP (current US$)
# 253  St. Vincent and the Grenadines          VCT  GDP (current US$)
# 254                   Venezuela, RB          VEN  GDP (current US$)
# 255          British Virgin Islands          VGB  GDP (current US$)
# 256           Virgin Islands (U.S.)          VIR  GDP (current US$)
# 257                        Viet Nam          VNM  GDP (current US$)
# 258                         Vanuatu          VUT  GDP (current US$)
# 259                           World          WLD  GDP (current US$)
# 260                           Samoa          WSM  GDP (current US$)
# 261                          Kosovo          XKX  GDP (current US$)
# 262                     Yemen, Rep.          YEM  GDP (current US$)
# 263                    South Africa          ZAF  GDP (current US$)
# ...

# %%
# view the shape of the data
gdp.shape
# Out:
# (266, 68)

# %%
# view the data types of the data
print("list of column and datatypes  in the data:")
gdp.dtypes

# %%
# view the data information
gdp.info()

# %%
# generate stats summary of the data
gdp.describe(include='all')

# %% [markdown]
# # World Country List Data

# %% [markdown]
# Load libaries

# %%
import pandas as pd

# %% [markdown]
# Load dataset

# %%
country_list = pd.read_csv("../data/raw/world-country-list.csv")

# %% [markdown]
# Preview data

# %%
country_list.head(10)

# %%
country_list.tail(10)

# %%
# check data informaton
country_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              262 non-null    object
#  1   Alpha-2 code         262 non-null    object
#  2   Alpha-3 code         262 non-null    object
#  3   Numeric code         262 non-null    object
#  4   Latitude (average)   262 non-null    object
#  5   Longitude (average)  262 non-null    object
# dtypes: object(6)
# memory usage: 12.4+ KB

# %%
# check countries list shape (row and column)
country_list.shape
# Out:
# (262, 6)

# %% [markdown]
# ## Oil Producing Countries Data

# %%
import pandas as pd # for data exploration and manipulation

# %%
oil_states = pd.read_csv('../data/raw/oil-producing-nation.csv')

# %%
oil_states.head(10) # view the head of the data
# Out:
#   Country Code                Country
# 0          USA          United States
# 1          SAU          Saudi Arabia
# 2          RUS                 Russia
# 3          CAN                 Canada
# 4          IRQ                  Iraq
# 5          CHN                  China
# 6          ARE  United Arab Emirates
# 7          IRN                  Iran
# 8          BRA                 Brazil
# 9          KWT                Kuwait

# %%
oil_states.tail(10) # view the tail of the data
# Out:
#    Country Code      Country
# 87          PHL  Philippines
# 88          LTU    Lithuania
# 89          KGZ   Kyrgyzstan
# 90          TJK   Tajikistan
# 91          GEO      Georgia
# 92          TWN       Taiwan
# 93          SVK     Slovakia
# 94          MAR      Morocco
# 95          JOR       Jordan
# 96          ESP        Spain

# %%
oil_states.describe() # view the data information
# Out:
#        Country Code        Country
# count            97             97
# unique           97             97
# top             USA  United States
# freq              1              1
